# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mlxtend.regressor import LinearRegression

# %%
df = pd.read_csv('/content/drive/My Drive/Keras/LearnKeras-master/1.LinearRegression/IowaHousingPrices.csv')

# %%
df.head(10)
# Out:
#    SquareFeet  SalePrice
# 0        1710     208500
# 1        1262     181500
# 2        1786     223500
# 3        1717     140000
# 4        2198     250000
# 5        1362     143000
# 6        1694     307000
# 7        2090     200000
# 8        1774     129900
# 9        1077     118000

# %%
X = np.array(df.SquareFeet)[:, np.newaxis]
y = np.array(df.SalePrice).astype(np.float)

# %%
xmodel = LinearRegression(epochs = 30)

# %%
xmodel.fit(X, y)
# Out:
# /usr/local/lib/python3.6/dist-packages/mlxtend/_base/_regressor.py:19: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(y[0], float):

# %%
print((X[0:10]))
print((y[0:10]))
# Out:
# [[1710]
#  [1262]
#  [1786]
#  [1717]
#  [2198]
#  [1362]
#  [1694]
#  [2090]
#  [1774]
#  [1077]]
# [208500. 181500. 223500. 140000. 250000. 143000. 307000. 200000. 129900.
#  118000.]

# %%
areas = X[:4][:, np.newaxis]

# %%
type(areas)
# Out:
# numpy.ndarray

# %%
xmodel.predict(X[5][:, np.newaxis])
# Out:
# array([164480.57476794])
