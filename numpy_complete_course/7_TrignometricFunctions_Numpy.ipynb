# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %%
ran = np.pi
a = np.linspace(-ran *3, ran*3 ,500)
plt.plot(a,np.sin(a))

# %%
plt.plot(a,np.cos(a))

# %%
plt.plot(a,np.tan(a))

# %%
np.arcsin(.5)
# Out:
# 0.5235987755982988

# %%
#arccos,arctan,sinh,cosh,tanh,arcsinh,arccosh,arctanh.

# %%
p = np.pi
np.rad2deg(5*p)
# Out:
# 900.0

# %%
np.deg2rad(360)
# Out:
# 6.283185307179586

# %%
np.hypot(4,3)
# Out:
# 5.0
